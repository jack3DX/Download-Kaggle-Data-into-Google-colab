# %% [markdown]
# ## It's important to reset your token and download the new one before using it here.

# %%
from google.colab import files
files.upload() 
#Choose the json file once the button pops
# Out:
#      <input type="file" id="files-ce7f4604-f725-490f-8921-d748907f51e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce7f4604-f725-490f-8921-d748907f51e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"jacksonkolling","key":"afe44cea12d998457fc37821d24c31bc"}'}

# %%
# !rm -r ~/.kaggle #in case there's any previous directory name as kaggle, it'll be removed
# !mkdir ~/.kaggle #creating a new directory
# !mv ./kaggle.json ~/.kaggle/ #moving the json file to it
# !chmod 600 ~/.kaggle/kaggle.json #changing permissions to the file
# !kaggle datasets list #if everything went ok, you may see a list of available datasets
# Out:
# rm: cannot remove '/root/.kaggle': No such file or directory
# ref                                                            title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# datasets/muratkokludataset/date-fruit-datasets                 Date Fruit Datasets                              408KB  2022-04-03 09:25:39           1737        326  0.9375
# datasets/piterfm/2022-ukraine-russian-war                      2022 Ukraine Russia War                            2KB  2022-04-21 09:38:14          10180        558  1.0
# datasets/muratkokludataset/acoustic-extinguisher-fire-dataset  Acoustic Extinguisher Fire Dataset               621KB  2022-04-02 22:59:36            206        286  0.9375
# ...

# %% [markdown]
# For the next step, there's multiple ways of loading data. I like to follow the process below (keep in mind that this is just an example):
#
# * Find the desired dataset on Kaggle website and look for the data tab.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Look for the field like the one in the image below and copy its content:
# ![image.png](data:image/png;base64,...)

# %%
#Remember to use "!" before the copied comand
! kaggle competitions download -c home-data-for-ml-course
# Out:
# ...
#   0% 0.00/386k [00:00<?, ?B/s]
# 100% 386k/386k [00:00<00:00, 85.1MB/s]

# %%
#Unzip it (you may also create a new directory before unzipping it)
! unzip home-data-for-ml-course.zip
# Out:
# Archive:  home-data-for-ml-course.zip
#   inflating: data_description.txt
#   inflating: sample_submission.csv
#   inflating: sample_submission.csv.gz
#   inflating: test.csv
#   inflating: test.csv.gz
#   inflating: train.csv
#   inflating: train.csv.gz

# %%
#To read data, you may use the following command (/content is the default directory if you didn't create any):
file = '../content/train.csv'

#From here, you may import pandas and use, for instance, "read_csv" to load it
